# %% [markdown]
# ## Week 2

# %% [markdown]
# ### Exercise:
# Use and experience methods from previous lessons with given data. Try to search for other pandas methods to analyze the data such as `groupby()` and `read_csv()`.

# %%
# You can find covid related data under project's data folder 
base_url = "../data/covid/"
infected_dataset_url = base_url + "time_series_covid19_confirmed_global.csv"
recovered_dataset_url = base_url + "time_series_covid19_recovered_global.csv"
deaths_dataset_url = base_url + "time_series_covid19_deaths_global.csv"

# %% [markdown]
# #### Solution:

# %%
# Your code goes here

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('time_series_covid19_confirmed_global (1).csv')

# %%
print(df)
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
# 265            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  \
# ...

# %%
df.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '6/6/20', '6/7/20', '6/8/20', '6/9/20', '6/10/20', '6/11/20', '6/12/20',
#        '6/13/20', '6/14/20', '6/15/20'],
#       dtype='object', length=150)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=266, step=1)

# %%
df.info
# Out:
# <bound method DataFrame.info of     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
# 265            NaN                Lesotho -29.609988  28.233608        0
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
# 265            NaN                Lesotho -29.609988  28.233608        0
#
# ...

# %%
df.size
# Out:
# 39900

# %%
df.shape
# Out:
# (266, 150)

# %%
df.loc("")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\GECE\anaconda3\envs\Lovelace\lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     552             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     553         except KeyError:
# --> 554             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: ''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14508\562698431.py in ?()
# ----> 1 df.loc("")
#
# c:\Users\GECE\anaconda3\envs\Lovelace\lib\site-packages\pandas\core\indexing.py in ?(self, axis)
#     718         # we need to return a copy of ourselves
#     719         new_self = type(self)(self.name, self.obj)
#     720
#     721         if axis is not None:
# ...

# %%
df = pd.read_csv('time_series_covid19_recovered_global.csv')

# %%
df
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 248            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 249            NaN                  Yemen  15.552727  48.516388        0
# 250            NaN                Comoros -11.645500  43.333300        0
# 251            NaN             Tajikistan  38.861034  71.276093        0
# 252            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  \
# ...

# %%
df = pd.read_csv('time_series_covid19_deaths_global.csv')

# %%
df
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
# 265            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  \
# ...

# %%
selected_indexes = df.index[:7]

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=266, step=1)

# %%
selected_indexes = df.index[:10]  # İlk 10 indeksi seçme örneği

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
# 265            NaN                Lesotho -29.609988  28.233608        0
#
# ...

# %%
df.size
# Out:
# 39900

# %%
df.iloc[1]
# Out:
# Province/State        NaN
# Country/Region    Albania
# Lat               41.1533
# Long              20.1683
# 1/22/20                 0
#                    ...
# 6/11/20              1385
# 6/12/20              1416
# 6/13/20              1464
# 6/14/20              1521
# 6/15/20              1590
# Name: 1, Length: 150, dtype: object

# %%
df["Long"]
# Out:
# 0      65.000000
# 1      20.168300
# 2       1.659600
# 3       1.521800
# 4      17.873900
#          ...
# 261     6.613081
# 262    48.516388
# 263    43.333300
# 264    71.276093
# 265    28.233608
# Name: Long, Length: 266, dtype: float64

# %%
df["Long"].to_frame()
# Out:
#           Long
# 0    65.000000
# 1    20.168300
# 2     1.659600
# 3     1.521800
# 4    17.873900
# ..         ...
# 261   6.613081
# 262  48.516388
# 263  43.333300
# 264  71.276093
# 265  28.233608
#
# [266 rows x 1 columns]

# %%
df[["Long", "Country/Region"]]
# Out:
#           Long         Country/Region
# 0    65.000000            Afghanistan
# 1    20.168300                Albania
# 2     1.659600                Algeria
# 3     1.521800                Andorra
# 4    17.873900                 Angola
# ..         ...                    ...
# 261   6.613081  Sao Tome and Principe
# 262  48.516388                  Yemen
# 263  43.333300                Comoros
# 264  71.276093             Tajikistan
# 265  28.233608                Lesotho
#
# [266 rows x 2 columns]

# %%
df[1:3]
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  6/10/20  \
# 1        0        0        0  ...    1232    1246    1263    1299     1341
# 2        0        0        0  ...   10050   10154   10265   10382    10484
#
#    6/11/20  6/12/20  6/13/20  6/14/20  6/15/20
# 1     1385     1416     1464     1521     1590
# 2    10589    10698    10810    10919    11031
#
# [2 rows x 150 columns]

# %%
df.loc['France': 'Italy']
# Out:
# Empty DataFrame
# Columns: [Province/State, Country/Region, Lat, Long, 1/22/20, 1/23/20, 1/24/20, 1/25/20, 1/26/20, 1/27/20, 1/28/20, 1/29/20, 1/30/20, 1/31/20, 2/1/20, 2/2/20, 2/3/20, 2/4/20, 2/5/20, 2/6/20, 2/7/20, 2/8/20, 2/9/20, 2/10/20, 2/11/20, 2/12/20, 2/13/20, 2/14/20, 2/15/20, 2/16/20, 2/17/20, 2/18/20, 2/19/20, 2/20/20, 2/21/20, 2/22/20, 2/23/20, 2/24/20, 2/25/20, 2/26/20, 2/27/20, 2/28/20, 2/29/20, 3/1/20, 3/2/20, 3/3/20, 3/4/20, 3/5/20, 3/6/20, 3/7/20, 3/8/20, 3/9/20, 3/10/20, 3/11/20, 3/12/20, 3/13/20, 3/14/20, 3/15/20, 3/16/20, 3/17/20, 3/18/20, 3/19/20, 3/20/20, 3/21/20, 3/22/20, 3/23/20, 3/24/20, 3/25/20, 3/26/20, 3/27/20, 3/28/20, 3/29/20, 3/30/20, 3/31/20, 4/1/20, 4/2/20, 4/3/20, 4/4/20, 4/5/20, 4/6/20, 4/7/20, 4/8/20, 4/9/20, 4/10/20, 4/11/20, 4/12/20, 4/13/20, 4/14/20, 4/15/20, 4/16/20, 4/17/20, 4/18/20, 4/19/20, 4/20/20, 4/21/20, 4/22/20, 4/23/20, 4/24/20, 4/25/20, 4/26/20, ...]
# Index: []
#
# [0 rows x 150 columns]

# %%
a = df.loc['France': 'Italy', 'Long']

# %%
a
# Out:
# Series([], Name: Long, dtype: float64)

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a.dtypes
# Out:
# dtype('float64')

# %%
df['Long'] > 20.168300
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 261    False
# 262     True
# 263     True
# 264     True
# 265     True
# Name: Long, Length: 266, dtype: bool

# %%
df.drop(1)
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# 5              NaN    Antigua and Barbuda  17.060800 -61.796400        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
# 265            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  \
# ...

# %%
df.drop(columns=["Long", "Province/State"])
# Out:
#             Country/Region        Lat  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0              Afghanistan  33.000000        0        0        0        0
# 1                  Albania  41.153300        0        0        0        0
# 2                  Algeria  28.033900        0        0        0        0
# 3                  Andorra  42.506300        0        0        0        0
# 4                   Angola -11.202700        0        0        0        0
# ..                     ...        ...      ...      ...      ...      ...
# 261  Sao Tome and Principe   0.186360        0        0        0        0
# 262                  Yemen  15.552727        0        0        0        0
# 263                Comoros -11.645500        0        0        0        0
# 264             Tajikistan  38.861034        0        0        0        0
# 265                Lesotho -29.609988        0        0        0        0
#
#      1/26/20  1/27/20  1/28/20  1/29/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  \
# ...

# %%
df.drop(["Long", "Province/State"], axis=1)
# Out:
#             Country/Region        Lat  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0              Afghanistan  33.000000        0        0        0        0
# 1                  Albania  41.153300        0        0        0        0
# 2                  Algeria  28.033900        0        0        0        0
# 3                  Andorra  42.506300        0        0        0        0
# 4                   Angola -11.202700        0        0        0        0
# ..                     ...        ...      ...      ...      ...      ...
# 261  Sao Tome and Principe   0.186360        0        0        0        0
# 262                  Yemen  15.552727        0        0        0        0
# 263                Comoros -11.645500        0        0        0        0
# 264             Tajikistan  38.861034        0        0        0        0
# 265                Lesotho -29.609988        0        0        0        0
#
#      1/26/20  1/27/20  1/28/20  1/29/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  \
# ...

# %%
df.drop(["Long", "Province/State"], axis="columns")
# Out:
#             Country/Region        Lat  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0              Afghanistan  33.000000        0        0        0        0
# 1                  Albania  41.153300        0        0        0        0
# 2                  Algeria  28.033900        0        0        0        0
# 3                  Andorra  42.506300        0        0        0        0
# 4                   Angola -11.202700        0        0        0        0
# ..                     ...        ...      ...      ...      ...      ...
# 261  Sao Tome and Principe   0.186360        0        0        0        0
# 262                  Yemen  15.552727        0        0        0        0
# 263                Comoros -11.645500        0        0        0        0
# 264             Tajikistan  38.861034        0        0        0        0
# 265                Lesotho -29.609988        0        0        0        0
#
#      1/26/20  1/27/20  1/28/20  1/29/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  \
# ...

# %%
df[["Long", "Province/State"]]
# Out:
#           Long Province/State
# 0    65.000000            NaN
# 1    20.168300            NaN
# 2     1.659600            NaN
# 3     1.521800            NaN
# 4    17.873900            NaN
# ..         ...            ...
# 261   6.613081            NaN
# 262  48.516388            NaN
# 263  43.333300            NaN
# 264  71.276093            NaN
# 265  28.233608            NaN
#
# [266 rows x 2 columns]

# %%
df[["Long"]]/10
# Out:
#          Long
# 0    6.500000
# 1    2.016830
# 2    0.165960
# 3    0.152180
# 4    1.787390
# ..        ...
# 261  0.661308
# 262  4.851639
# 263  4.333330
# 264  7.127609
# 265  2.823361
#
# [266 rows x 1 columns]

# %%
langs = pd.Series(
    ['French', 'German', 'Italian'],
    index=['France', 'Germany', 'Italy'],
    name='Language'
)

# %%
langs
# Out:
# France      French
# Germany     German
# Italy      Italian
# Name: Language, dtype: object

# %%
df["language"] = langs

# %%
df
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
# 265            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/7/20  6/8/20  6/9/20  \
# ...

# %%
df = df.drop(["language"], axis="columns")

# %%
df
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
# 265            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  \
# ...

# %%
new_row = pd.Series({
    'Population': 83.000,
    'Continent': 'Europe',
    'Language': 'Türkçe'
}, name="Türkiye"
)

# %%
new_row
# Out:
# Population      83.0
# Continent     Europe
# Language      Türkçe
# Name: Türkiye, dtype: object

# %%
pd.concat([df, new_row.to_frame().T], ignore_index=False)
# Out:
#         Province/State Country/Region        Lat       Long  1/22/20  1/23/20  \
# 0                  NaN    Afghanistan  33.000000  65.000000      0.0      0.0
# 1                  NaN        Albania  41.153300  20.168300      0.0      0.0
# 2                  NaN        Algeria  28.033900   1.659600      0.0      0.0
# 3                  NaN        Andorra  42.506300   1.521800      0.0      0.0
# 4                  NaN         Angola -11.202700  17.873900      0.0      0.0
# ...                ...            ...        ...        ...      ...      ...
# 262                NaN          Yemen  15.552727  48.516388      0.0      0.0
# 263                NaN        Comoros -11.645500  43.333300      0.0      0.0
# 264                NaN     Tajikistan  38.861034  71.276093      0.0      0.0
# 265                NaN        Lesotho -29.609988  28.233608      0.0      0.0
# Türkiye            NaN            NaN        NaN        NaN      NaN      NaN
#
# ...
